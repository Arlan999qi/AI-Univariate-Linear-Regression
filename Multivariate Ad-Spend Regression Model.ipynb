# %%
import numpy as np
import matplotlib.pyplot as plt
X_train = np.array([[500, 1200, 200], [1000, 800, 500], [300, 2000, 100]])
y_train = np.array([15000, 22000, 18000])

# %%
w_init = np.zeros(3)
b_init = 0

# %%
def compute_cost(X, y, w, b):
    m = X.shape[0]
    cost = 0
    for i in range(m):
        cost += ((np.dot(X[i], w)) - y[i]) ** 2
    cost = 1 / (2 * m) * cost
    return cost

# %%
def compute_gradient(X, y, w, b):
    m, n = X.shape
    dj_dw = np.zeros(3)
    dj_db = 0
    for i in range(m):
        err = (np.dot(X[i], w)) - y[i]
        for j in range(n):
            dj_dw[j] += err * X[i, j]
        dj_db += err
    dj_dw = dj_dw / m
    dj_db = dj_db / m
    return dj_dw, dj_db

# %%
def gradient_descent(X, y, w_in, b_in, alpha, numb_iter, cost_function, gradient_function):
    J_hist = []
    w = w_in
    b = b_in
    for i in range(numb_iter):
        dj_dw, dj_db = gradient_function(X, y, w, b)
        w = w - alpha * dj_dw
        b = b - alpha * dj_db
        J_hist.append(cost_function(X, y, w, b))
    return w, b, J_hist

# %%
tmp_alpha = 0.0000005
iterations = 100000
w_final, b_final, cost_history = gradient_descent(X_train, y_train, w_init, b_init, tmp_alpha, iterations, compute_cost,
                                                  compute_gradient)
print(f"w_final = {w_final}, b_final = {b_final}")
print(f"cost history = {cost_history}")
# Out:
# w_final = [-5.82034913  7.7075195  43.30830875], b_final = -0.3113677797921376
# cost history = [16318008.333333332, 9523916.68460648, 7226760.840323331, 5546832.1582084205, 4265716.708094394, 3287321.1037503746, 2540076.9591226103, 1969371.4896319578, 1533495.8658683249, 1200595.3634403483, 946341.2145614452, 752152.5345370707, 603838.3343523766, 490560.3696213896, 404041.02549657115, 337958.3456606127, 287483.990982704, 248930.3594624341, 219481.07715730352, 196985.16297358894, 179799.8238163098, 166670.39075284312, 156638.6213025393, 148972.66610827058, 143113.58159117546, 138634.47945611586, 135209.3274818954, 132589.12139625155, 130583.68635271417, 129047.77796688765, 127870.46710385592, 126967.03260191632, 126272.76941087842, 125738.25961155846, 125325.76069806989, 125006.44715984343, 124758.3037638983, 124564.51656750667, 124412.24406811764, 124291.67867979803, 124195.32994403326, 124117.47708821915, 124053.75092196408, 124000.81451402922, 123956.11931212545, 123917.71888152626, 123884.1266495552, 123854.2072591724, 123827.09359122853, 123802.12339092688, 123778.790866837, 123756.7097250654, 123735.58493692073, 123715.1911767167, 123695.35635382961, 123675.94903545434, 123656.86884083552, 123638.03910495868, 123619.40127549268, 123600.91063351244, 123582.53302524131, 123564.24236593518, 123546.01873351018, 123527.84691255557, 123509.71528234487, 123491.61496755775, 123473.5391896568, 123455.48277150014, 123437.44175900184, 123419.41313217342, 123401.39458443342, 123383.38435406066, 123365.38109546452, 123347.38378087338, 123329.39162524384, 123311.40402891483, 123293.42053381338, 123275.4407899966, 123257.46453010985, 123239.49154987291, 123221.52169317918, 123203.5548407113, 123185.59090125347, 123167.62980504919, 123149.67149873305, 123131.71594145746, 123113.76310193408, 123095.81295617805, 123077.86548578065, 123059.92067659163, 123041.97851771438, 123024.03900073575, 123006.10211914203, 122988.16786786712, 122970.23624295084, 122952.30724128091, 122934.38086038924, 122916.45709829988, 122898.53595341524, 122880.61742442325, 122862.70151023491, 122844.78820992558, 122826.87752270108, 122808.9694478644, 122791.06398479201, 122773.16113291983, 122755.26089172596, 122737.3632607228, 122719.46823944584, 122701.57582745375, 122683.68602431851, 122665.7988296209, 122647.91424295442, 122630.03226391699, 122612.15289211107, 122594.27612714621, 122576.40196863172, 122558.53041618064, 122540.66146940619, 122522.79512792506, 122504.9313913554, 122487.07025931324, 122469.21173141737, 122451.355807287, 122433.50248654182, 122415.65176880045, 122397.80365368325, 122379.95814080929, 122362.11522980024, 122344.27492027644, 122326.43721185712, 122308.60210416385, 122290.7695968172, 122272.93968943652, 122255.11238164589, 122237.287673063, 122219.46556330992, 122201.64605200847, 122183.82913877911, 122166.01482324285, 122148.20310502128, 122130.39398373585, 122112.5874590076, 122094.7835304579, 122076.98219770883, 122059.18346038091, 122041.38731809641, 122023.59377047652, 122005.80281714452, 121988.01445771923, 121970.22869182532, 121952.44551908279, 121934.66493911439, 121916.88695154237, 121899.11155598787, 121881.33875207325, 121863.56853942064, 121845.80091765303, 121828.0358863913, 121810.27344525946, 121792.51359387855, 121774.75633187164, 121757.00165885998, 121739.24957446806, 121721.50007831692, 121703.7531700298, 121686.00884922939, 121668.26711553847, 121650.52796857944, 121632.79140797572, 121615.05743334975, 121597.32604432467, 121579.59724052386, 121561.8710215692, 121544.14738708499, 121526.42633669464, 121508.70787002097, 121490.99198668609, 121473.27868631511, 121455.56796853081, 121437.85983295651, 121420.1542792157, 121402.45130693205, 121384.75091573028, 121367.05310523175, 121349.35787506102, 121331.6652248431, 121313.97515420099, 121296.28766275839, 121278.60275013938, 121260.92041596875, 121243.240659869, 121225.56348146626, 121207.888880382, 121190.21685624318, 121172.54740867292, 121154.8805372947, 121137.21624173463, 121119.55452161585, 121101.89537656437, 121084.23880620238, 121066.584 ...

# %%
def compute_model_prediction(X, w, b):
    p = np.zeros(3)
    m = X_train.shape[0]
    for i in range(m):
        p[i] = np.dot(X[i], w) - b
    return p

# %%
predicted_sales = compute_model_prediction(X_train, w_final, b_final)

# %%
m = X_train.shape[0]
print(f"For the first week our prediction is {predicted_sales[0]}, and actual sales are {y_train[0]}")
print(f"For the first week our prediction is {predicted_sales[1]}, and actual sales are {y_train[1]}")
print(f"For the first week our prediction is {predicted_sales[2]}, and actual sales are {y_train[2]}")
# Out:
# For the first week our prediction is 15000.821952087454, and actual sales are 15000
# For the first week our prediction is 22000.132215383164, and actual sales are 22000
# For the first week our prediction is 18000.07650016233, and actual sales are 18000

# %% [markdown]
# Wow! The results are really accurate!!!

# %% [markdown]
# The "Future Spend" Prediction: If the company plans to spend $1,500  on  Instagram, $500 on Google, and $1,000 on Influencers, what are the predicted sales?

# %%
X_hypothetical = np.array([1500, 500, 1000])

# %%
prediction = (np.dot(X_hypothetical, w_final)) - b_final
print(f"In that case the company will get {prediction}$ in sales.")
# Out:
# In that case the company will get 38431.85617838969$ in sales.

# %% [markdown]
# Wow! They should really try this approach!
